# %%
import pandas as pd
import numpy as np

# %%
xlsx = pd.ExcelFile(r'C:\Users\hassan\Desktop\Hallo Hallo financial report.xlsx')

# %%
print(xlsx)

# %%
xlsx.sheet_names
# Out:
# ['Sheet1', 'Sheet7', 'Sheet6', 'Sheet5', 'Sheet3', 'Sheet4', 'Sheet2']

# %%
'df =pd.read_excel((Hallo Hallo financial report,sheet_name='Sheet2')
# Out:
#   Input In [44]
#     'df =pd.read_excel((Hallo Hallo financial report,sheet_name='Sheet2')
#                                                                  ^
# SyntaxError: invalid syntax

# %%
file_path=pd.read_excel(r'C:\Users\hassan\Desktop\Hallo Hallo financial report.xlsx',sheet_name=None)
# Out:
# C:\Users\hassan\anaconda3\envs\exceldata\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
print(file_path)
# Out:
# {'Sheet1':                     Unnamed: 0 HALLO HALLO COMMUNICATION LTD  \
# 0   FINANCIAL REPORT 2018/2019                           NaN
# 1                          NaN                           NaN
# 2                          NaN                       ACCOUNT
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# 5                          NaN                        INCOME
# 6                          NaN            COMMISSION  DEALER
# 7                          NaN                           NaN
# 8                          NaN                           NaN
# 9                          NaN                           NaN
# 10                         NaN                           NaN
# 11                         NaN                           NaN
# 12                         NaN                           NaN
# 13                         NaN                           NaN
# ...

# %%
file_path=pd.read_excel(r'C:\Users\hassan\Desktop\Hallo Hallo financial report.xlsx','Sheet2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 file_path=pd.read_excel(r'C:\Users\hassan\Desktop\Hallo Hallo financial report.xlsx','Sheet2')
#
# NameError: name 'pd' is not defined

# %%
print(file_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 print(file_path)
#
# NameError: name 'file_path' is not defined

# %%
path_file=pd.read_excel(r'C:\Users\hassan\Desktop\Hallo Hallo financial report.xlsx','Sheet2',header =None,names=['incentives','cash'])

# %%
print(path_file)
# Out:
#                        incentives       cash
# 0      Dealear Resource Incentive        NaN
# 1                   Quarter 1 & 2        NaN
# 2              April to June 2018   180000.0
# 3          July to September 2018   180000.0
# 4                           Total   360000.0
# 5                             NaN        NaN
# 6                   Quarter 3 & 4        NaN
# 7   October 2017 to December 2017   180000.0
# 8     January 2018  to March 2018   180000.0
# 9                           Total   360000.0
# 10                            NaN        NaN
# 11                         Half 2        NaN
# 12     October 2017 to March 2018   169601.0
# 13   April 2018 to September 2018   165699.0
# 14     October 2018 to March 2019   183127.0
# 15                          Total   518427.0
# 16                            NaN        NaN
# 17                            NaN        NaN
# 18                            NaN        NaN
# 19                  Quarter 3 & 4        NaN
# ...

# %%
path_file.corr()
# Out:
#       cash
# cash   1.0

# %%
path_file.cov()
# Out:
#               cash
# cash  1.954299e+11

# %%
path_file.dropna()
# Out:
#                        incentives       cash
# 2              April to June 2018   180000.0
# 3          July to September 2018   180000.0
# 4                           Total   360000.0
# 7   October 2017 to December 2017   180000.0
# 8     January 2018  to March 2018   180000.0
# 9                           Total   360000.0
# 12     October 2017 to March 2018   169601.0
# 13   April 2018 to September 2018   165699.0
# 14     October 2018 to March 2019   183127.0
# 15                          Total   518427.0
# 20  October 2018 to December 2018   165000.0
# 21    January 2019  to March 2019   180000.0
# 24             April to June 2019   165000.0
# 25              July to September   185000.0
# 26                Bonus half 2019   171099.0
# 27                          Total   521099.0
# 29                    Grand total  2104526.0
# 31             Care Desk - Gilgil   225000.0

# %%
path_file.sum()
# Out:
# C:\Users\hassan\AppData\Local\Temp\ipykernel_10648\2045701445.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   path_file.sum()
# cash    6538578.0
# dtype: float64

# %%
path_file.describe()
# Out:
#                cash
# count  1.900000e+01
# mean   3.441357e+05
# std    4.420746e+05
# min    1.650000e+05
# 25%    1.755495e+05
# 50%    1.800000e+05
# 75%    3.525000e+05
# max    2.104526e+06
